-- %%
USE master;
GO

IF DB_ID('Employee') IS NULL
    CREATE DATABASE Employee;
GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.005

-- %%
USE master;
GO

ALTER DATABASE Employee
SET MULTI_USER;
GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.084

-- %%
USE Employee;
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.009

-- %%
USE Employee;
GO

IF OBJECT_ID('dbo.Employeess', 'U') IS NOT NULL
    DROP TABLE dbo.Employeess;
GO

CREATE TABLE Employeess
(
  EmployeeID INT IDENTITY(1,1) PRIMARY KEY,
  FirstName NVARCHAR(50),
  LastName NVARCHAR(50),
  Gender NVARCHAR(10),
  BirthDate DATE,
  Email NVARCHAR(100) UNIQUE,
  Phone NVARCHAR(20),
  HireDate DATE,
  JobTitle NVARCHAR(100),
  Salary DECIMAL(10,2),
  Department NVARCHAR(100)
);
GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.043

-- %%
update Employeess set salary =90000
where EmployeeID =1
-- Out:
-- (0 rows affected)
-- Total execution time: 00:00:01

-- %%
INSERT INTO Employeess
    (
    FirstName,
    LastName,
    Gender,
    BirthDate,
    Email,
    Phone,
    HireDate,
    JobTitle,
    Salary,
    Department
    )
VALUES
    ('Ahmed', 'Ali', 'Male', '1998-05-10', 'ahmed@example.com', '01012345678', '2024-01-15', 'Data Analyst', 12000, 'Data'),

    ('Sara', 'Mohamed', 'Female', '1999-08-20', 'sara@example.com', '01198765432', '2023-07-01', 'Software Engineer', 15000, 'IT'),

    ('Omar', 'Hassan', 'Male', '1997-12-01', 'omar@example.com', '01234567890', '2022-03-10', 'Database Administrator', 18000, 'Database'),

    ('Mona', 'Khaled', 'Female', '1996-11-25', 'mona@example.com', '01511223344', '2021-09-15', 'HR Specialist', 10000, 'HR'),

    ('Youssef', 'Mahmoud', 'Male', '1995-02-18', 'youssef@example.com', '01099887766', '2020-06-20', 'Project Manager', 22000, 'Management');
GO
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.999

-- %%
INSERT INTO Employeess
  (
  FirstName,
  LastName,
  Gender,
  BirthDate,
  Email,
  Phone,
  HireDate,
  JobTitle,
  Salary,
  Department
  )
VALUES
  ('Ali', 'Ibrahim', 'Male', '1997-03-15', 'ali@example.com', '01011111111', '2023-01-10', 'Data Engineer', 18000, 'Data'),

  ('Mariam', 'Adel', 'Female', '1998-07-22', 'mariam@example.com', '01122222222', '2022-05-18', 'Business Analyst', 16000, 'BI'),

  ('Hassan', 'Samy', 'Male', '1996-12-05', 'hassan@example.com', '01233333333', '2021-09-01', 'Backend Developer', 20000, 'IT'),

  ('Nour', 'Ahmed', 'Female', '1999-10-30', 'nour@example.com', '01544444444', '2024-02-15', 'HR Specialist', 11000, 'HR'),

  ('Karim', 'Mostafa', 'Male', '1995-04-11', 'karim@example.com', '01055555555', '2020-08-20', 'Project Manager', 25000, 'Management'),

  ('Salma', 'Tarek', 'Female', '1997-08-18', 'salma@example.com', '01166666666', '2023-03-12', 'Data Analyst', 14500, 'Data'),

  ('Omar', 'Nabil', 'Male', '1994-01-25', 'omar.n@example.com', '01277777777', '2019-11-05', 'Database Administrator', 21000, 'Database'),

  ('Aya', 'Maher', 'Female', '2000-06-09', 'aya@example.com', '01588888888', '2025-01-01', 'Software Engineer', 17000, 'IT'),

  ('Mahmoud', 'Fathy', 'Male', '1993-09-14', 'mahmoud@example.com', '01099999999', '2018-07-30', 'System Administrator', 23000, 'Infrastructure'),

  ('Reem', 'Kamal', 'Female', '1998-02-27', 'reem@example.com', '01112345678', '2024-04-01', 'UI/UX Designer', 15000, 'Design');
GO
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.026

-- %%
SELECT *
FROM Employeess;
GO
-- Out:
-- (15 rows affected)
--
-- EmployeeID | FirstName | LastName | Gender | BirthDate  | Email               | Phone       | HireDate   | JobTitle               | Salary   | Department
-- -----------+-----------+----------+--------+------------+---------------------+-------------+------------+------------------------+----------+---------------
-- 2          | Sara      | Mohamed  | Female | 1999-08-20 | sara@example.com    | 01198765432 | 2023-07-01 | Senior Project Manager | 16500.00 | IT
-- 3          | Omar      | Hassan   | Male   | 1997-12-01 | omar@example.com    | 01234567890 | 2022-03-10 | Database Administrator | 18000.00 | Database
-- 4          | Mona      | Khaled   | Female | 1996-11-25 | mona@example.com    | 01511223344 | 2021-09-15 | HR Specialist          | 10000.00 | HR
-- 5          | Youssef   | Mahmoud  | Male   | 1995-02-18 | youssef@example.com | 01099887766 | 2020-06-20 | Project Manager        | 22000.00 | Management
-- ...

-- %%
select FirstName, lastname, salary
from Employeess
-- Out:
-- (14 rows affected)
--
-- FirstName | lastname | salary
-- ----------+----------+---------
-- Sara      | Mohamed  | 15000.00
-- Omar      | Hassan   | 18000.00
-- Mona      | Khaled   | 10000.00
-- Youssef   | Mahmoud  | 22000.00
-- Ali       | Ibrahim  | 18000.00
-- Mariam    | Adel     | 16000.00
-- Hassan    | Samy     | 20000.00
-- Nour      | Ahmed    | 11000.00
-- Karim     | Mostafa  | 25000.00
-- Salma     | Tarek    | 14500.00
-- Omar      | Nabil    | 21000.00
-- Aya       | Maher    | 17000.00
-- Mahmoud   | Fathy    | 23000.00
-- Reem      | Kamal    | 15000.00
-- (14 rows)
--
-- Total execution time: 00:00:00.011

-- %%
select Department
from Employeess
-- Out:
-- (15 rows affected)
--
-- Department
-- --------------
-- IT
-- Database
-- HR
-- Management
-- Data
-- BI
-- IT
-- HR
-- Management
-- Data
-- Database
-- IT
-- Infrastructure
-- Design
-- Data
-- (15 rows)
--
-- Total execution time: 00:00:00.006

-- %%
select *
from Employeess
where salary >1800;
-- Out:
-- (14 rows affected)
--
-- EmployeeID | FirstName | LastName | Gender | BirthDate  | Email               | Phone       | HireDate   | JobTitle               | Salary   | Department
-- -----------+-----------+----------+--------+------------+---------------------+-------------+------------+------------------------+----------+---------------
-- 2          | Sara      | Mohamed  | Female | 1999-08-20 | sara@example.com    | 01198765432 | 2023-07-01 | Software Engineer      | 15000.00 | IT
-- 3          | Omar      | Hassan   | Male   | 1997-12-01 | omar@example.com    | 01234567890 | 2022-03-10 | Database Administrator | 18000.00 | Database
-- 4          | Mona      | Khaled   | Female | 1996-11-25 | mona@example.com    | 01511223344 | 2021-09-15 | HR Specialist          | 10000.00 | HR
-- 5          | Youssef   | Mahmoud  | Male   | 1995-02-18 | youssef@example.com | 01099887766 | 2020-06-20 | Project Manager        | 22000.00 | Management
-- ...

-- %%
SELECT *
FROM Employeess
WHERE Gender = 'Female' AND HireDate > '2023-01-01';
-- Out:
-- (5 rows affected)
--
-- EmployeeID | FirstName | LastName | Gender | BirthDate  | Email             | Phone       | HireDate   | JobTitle          | Salary   | Department
-- -----------+-----------+----------+--------+------------+-------------------+-------------+------------+-------------------+----------+-----------
-- 2          | Sara      | Mohamed  | Female | 1999-08-20 | sara@example.com  | 01198765432 | 2023-07-01 | Software Engineer | 15000.00 | IT
-- 9          | Nour      | Ahmed    | Female | 1999-10-30 | nour@example.com  | 01544444444 | 2024-02-15 | HR Specialist     | 11000.00 | HR
-- 11         | Salma     | Tarek    | Female | 1997-08-18 | salma@example.com | 01166666666 | 2023-03-12 | Data Analyst      | 14500.00 | Data
-- 13         | Aya       | Maher    | Female | 2000-06-09 | aya@example.com   | 01588888888 | 2025-01-01 | Software Engineer | 17000.00 | IT
-- ...

-- %%
SELECT *
FROM Employeess
ORDER BY Salary DESC;
-- Out:
-- (15 rows affected)
--
-- EmployeeID | FirstName | LastName | Gender | BirthDate  | Email               | Phone       | HireDate   | JobTitle               | Salary   | Department
-- -----------+-----------+----------+--------+------------+---------------------+-------------+------------+------------------------+----------+---------------
-- 10         | Karim     | Mostafa  | Male   | 1995-04-11 | karim@example.com   | 01055555555 | 2020-08-20 | Senior Project Manager | 25000.00 | Management
-- 14         | Mahmoud   | Fathy    | Male   | 1993-09-14 | mahmoud@example.com | 01099999999 | 2018-07-30 | System Administrator   | 23000.00 | Infrastructure
-- 8          | Hassan    | Samy     | Male   | 1996-12-05 | hassan@example.com  | 01233333333 | 2021-09-01 | Backend Developer      | 22000.00 | IT
-- 5          | Youssef   | Mahmoud  | Male   | 1995-02-18 | youssef@example.com | 01099887766 | 2020-06-20 | Project Manager        | 22000.00 | Management
-- ...

-- %%
select Department, avg (salary) as avgsalary
from Employeess
group by Department;
-- Out:
-- (8 rows affected)
--
-- Department     | avgsalary
-- ---------------+-------------
-- BI             | 16000.000000
-- Data           | 16250.000000
-- Database       | 19500.000000
-- Design         | 15000.000000
-- HR             | 10500.000000
-- Infrastructure | 23000.000000
-- IT             | 17333.333333
-- Management     | 23500.000000
-- (8 rows)
--
-- Total execution time: 00:00:00.015

-- %%
select Department , count (*) as EmployeeCount
from Employeess
group by Department;
-- Out:
-- (8 rows affected)
--
-- Department     | EmployeeCount
-- ---------------+--------------
-- BI             | 1
-- Data           | 2
-- Database       | 2
-- Design         | 1
-- HR             | 2
-- Infrastructure | 1
-- IT             | 3
-- Management     | 2
-- (8 rows)
--
-- Total execution time: 00:00:00.015

-- %%
select FirstName + '  ' + LastName as  fullname,
  datediff (year ,birthdate,GETDATE ())as age
from Employeess
-- Out:
-- (14 rows affected)
--
-- fullname         | age
-- -----------------+----
-- Sara  Mohamed    | 27
-- Omar  Hassan     | 29
-- Mona  Khaled     | 30
-- Youssef  Mahmoud | 31
-- Ali  Ibrahim     | 29
-- Mariam  Adel     | 28
-- Hassan  Samy     | 30
-- Nour  Ahmed      | 27
-- Karim  Mostafa   | 31
-- Salma  Tarek     | 29
-- Omar  Nabil      | 32
-- Aya  Maher       | 26
-- Mahmoud  Fathy   | 33
-- Reem  Kamal      | 28
-- (14 rows)
--
-- Total execution time: 00:00:00.014

-- %%
SELECT *
FROM Employeess
WHERE YEAR(HireDate) = 2023;
-- Out:
-- (3 rows affected)
--
-- EmployeeID | FirstName | LastName | Gender | BirthDate  | Email             | Phone       | HireDate   | JobTitle          | Salary   | Department
-- -----------+-----------+----------+--------+------------+-------------------+-------------+------------+-------------------+----------+-----------
-- 2          | Sara      | Mohamed  | Female | 1999-08-20 | sara@example.com  | 01198765432 | 2023-07-01 | Software Engineer | 15000.00 | IT
-- 6          | Ali       | Ibrahim  | Male   | 1997-03-15 | ali@example.com   | 01011111111 | 2023-01-10 | Data Engineer     | 18000.00 | Data
-- 11         | Salma     | Tarek    | Female | 1997-08-18 | salma@example.com | 01166666666 | 2023-03-12 | Data Analyst      | 14500.00 | Data
-- (3 rows)
--
-- Total execution time: 00:00:00.025

-- %%
INSERT INTO Employeess
  (FirstName, LastName, Gender, BirthDate, Email, Phone, HireDate, JobTitle, Salary, Department)
VALUES
  ('Youssef', 'Ashraf', 'Male', '1996-05-20', 'yssef@example.com', '01234567890', '2024-06-01', 'Data Engineer', 19000, 'Data');
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.017

-- %%
update Employeess
set salary =salary *1.10
where Department='it'
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.019

-- %%
select *
from Employeess
where jobtitle like '%Developer%';
-- Out:
-- (1 row affected)
--
-- EmployeeID | FirstName | LastName | Gender | BirthDate  | Email              | Phone       | HireDate   | JobTitle          | Salary   | Department
-- -----------+-----------+----------+--------+------------+--------------------+-------------+------------+-------------------+----------+-----------
-- 8          | Hassan    | Samy     | Male   | 1996-12-05 | hassan@example.com | 01233333333 | 2021-09-01 | Backend Developer | 20000.00 | IT
-- (1 row)
--
-- Total execution time: 00:00:00.032

-- %%
select *
from Employeess
where EmployeeID = 2
-- Out:
-- (1 row affected)
--
-- EmployeeID | FirstName | LastName | Gender | BirthDate  | Email            | Phone       | HireDate   | JobTitle          | Salary   | Department
-- -----------+-----------+----------+--------+------------+------------------+-------------+------------+-------------------+----------+-----------
-- 2          | Sara      | Mohamed  | Female | 1999-08-20 | sara@example.com | 01198765432 | 2023-07-01 | Software Engineer | 15000.00 | IT
-- (1 row)
--
-- Total execution time: 00:00:00.009

-- %%
delete from Employeess

where EmployeeID = 1
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.026

-- %%
SELECT COUNT(*) AS TotalEmployees
FROM Employeess;
-- Out:
-- (1 row affected)
--
-- TotalEmployees
-- --------------
-- 15
-- (1 row)
--
-- Total execution time: 00:00:00.008

-- %%
UPDATE Employeess
SET JobTitle = 'Senior Project Manager'
WHERE EmployeeID
= 2;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.016
